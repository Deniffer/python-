# %%
import numpy as np
import pandas as pd
df=pd.read_csv("train_data01.csv",encoding="latin1")
len(df)
# Out:
# 20000

# %%
#DataFrame.sample(n=None, frac=None, replace=False, weights=None, random_state=None, axis=None)
#df_1=df.sample(n=20000)

# %%
#df[:500000].sample(n=20000).to_csv("data_until2015.csv",encoding="latin1")

# %%
#df.head(10)

# %%
def get_avg_view(word):#get single word avg_view count
    avg=0
    len_avg=0
    for i in range(len(df)):
        if word in df["body"].values[i]:
            len_avg+=1
            avg+=df["view_count"].values[i]
        else:
            contiue
    if len_avg==0:
        return 0
    return(avg/len_avg)

# %%
import re
def get_clean_words(text):
    result=[]
    result_fin=[]
    with open(text,encoding="utf-8")as key:
        for i in key:
            result.append(i)
    for i in range(len(result)):
        result_all=[]
        result_clean=re.findall("\".*?\"",result[i])
        for j in range(len(result_clean)):
            result_all.append(eval(result_clean[j]))
        result_fin.append(result_all)
    return result_fin
def get_clean_weight(text):
    num=[]
    all_num=[]
    with open(text,encoding="utf-8")as key_2:
        for i in key_2:
            num.append(i)
    for i in range(len(num)):
        all_num.append(re.findall("\..*?\*",num[i]))
    all_clean_num=[]
    for i in range(30):
        clean_num=[]
        for j in all_num[i]:
            j=j.strip(",")
            j=float(j.strip("*"))
            clean_num.append(j)
        clean_num=[i*(1/sum(clean_num)) for i in clean_num]
        all_clean_num.append(clean_num)
    len(all_clean_num[0])
    return all_clean_num

# %%
text="key_word_3.txt"
word=get_clean_words(text)
all_clean_num=get_clean_weight(text)

# %%
def get_avg_view(word):#get single word avg_view count
    avg=0
    len_avg=0
    for i in range(len(df)):
        if word in df["body"].values[i]:
            len_avg+=1
            avg+=df["view_count"].values[i]
        else:
            continue
    if len_avg==0:
        return 0
    return(avg/len_avg)
def topic_avg_view(word):
    topic_view=[]
    func = lambda x,y:x*y
    for i in range(len(word)):
        topic=[]
        for j in word[i]:
            topic.append(get_avg_view(j))
        topicViews=sum(map(func,topic,all_clean_num[i]))
        topic_view.append(topicViews)
    return topic_view
topic_avg_view(word)
# Out:
# [284.5469602679132,
#  324.0920108694164,
#  320.38878362202917,
#  403.23698309418177,
#  270.8841606009538,
#  347.7577402383627,
#  448.2244236666241,
#  262.29148711060424,
#  280.29129043846245,
#  320.68586047121386,
#  295.34823057985665,
#  326.588878826222,
#  316.3082116397793,
#  286.3888350798965,
#  340.8910142213143,
#  353.71029260018753,
#  323.05657066586963,
#  327.3714856141502,
#  345.65255021781104,
#  282.23935519197994,
#  346.03329466213137,
#  357.75332357123216,
#  319.97367858482625,
#  308.7213631031209,
#  317.1030614944986,
#  320.26750938235955,
#  329.3700342968348,
#  295.20165518972334,
#  324.1434048812858,
#  297.86735636013356]

# %%
df=df.fillna(0)

# %%
def get_avg_favor(word):#get single word avg_favor count
    avg=0
    len_avg=0
    for i in range(len(df)):
        if word in df["body"].values[i]:
            len_avg+=1
            avg+=df["favorite_count"].values[i]
        else:
            continue
    if len_avg==0:
        return 0
    return(avg/len_avg)
def topic_favor(word):
    topic_favorite=[]
    func=lambda x,y:x*y
    for i in range(len(word)):
        topic=[]
        for j in word[i]:
            topic.append(get_avg_favor(j))
        topic_favorite_count=sum(map(func,topic,all_clean_num[i]))
        topic_favorite.append(topic_favorite_count)
    return topic_favorite
topic_favor(word)
# Out:
# [0.15370093534979834,
#  0.1439455092214664,
#  0.18042576112156525,
#  0.19755625601687102,
#  0.1469737534285789,
#  0.1433830997381719,
#  0.1940541587099371,
#  0.13775730627132346,
#  0.1587694513334065,
#  0.15185068256936696,
#  0.16707597441067654,
#  0.15528161595142453,
#  0.16290258611328573,
#  0.16362518341110627,
#  0.1721950415706888,
#  0.17922000389990303,
#  0.16310600793657787,
#  0.17302418961059302,
#  0.16854586662349447,
#  0.16191563809842813,
#  0.15551798876195932,
#  0.15642912982605875,
#  0.16967858496864383,
#  0.1494826159969403,
#  0.1569304203489308,
#  0.16381003685937182,
#  0.1933183325762469,
#  0.1598162948705816,
#  0.164149685359714,
#  0.16710920367756354]

# %%
df.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1        id  \
# 0      383486       1133486  53161316
# 1       22133        772133  43772362
# 2       63109        813109  45062375
# 3      170538        920538  48172883
# 4       79309        829309  45551389
# 5       89785        839785  45874844
# 6      166204        916204  48050833
# 7      236461        986461  49864308
# 8       12016        762016  43454047
# 9      206164        956164  49123117
#
#                                                title  \
# 0  How can I successfully host my Telegram bot wr...
# 1  How to print a specific row of a pandas DataFr...
# 2   why * used before declaring a variable in python
# 3               I can't understand how to solve this
# 4  Pickling sklearn models and using them in web app
# 5                 Can't display icons in QListWidget
# 6                  How to remove popup title in kivy
# 7                       Graphene Resolve Python List
# 8     How to store jobs for APScheduler in MySQL db?
# 9  Python 3.6.4 - urllib.request.urlopen certific...
#
#                                                 body  accepted_answer_id  \
# 0  <p>I followed <a href="https://djangostars.com...                 0.0
# 1  <p>I have a massive dataframe, and I'm getting...          43773398.0
# 2  <p>I just started to learn python. I was follo...          45062446.0
# 3  <pre><code>i,j=int,int\nnum=int(input('Enter t...                 0.0
# 4  <p>I have created an sklearn model that I woul...                 0.0
# 5  <p>I'm trying to do something like <a href="ht...          45875226.0
# 6  <p>I've been wondering if there is a way to re...          48051442.0
# 7  <p>I am working with GraphQL in python am tryi...                 0.0
# 8  <p>I need to store all jobs for apscheduler in...                 0.0
# 9  <p>Trying to teach myself how to use urllib.re...                 0.0
#
#    answer_count  comment_count        creation_date  favorite_count  \
# 0             2              0  2018-11-05 19:57:01             0.0
# 1             4              1  2017-05-04 01:22:15             6.0
# 2             1              1  2017-07-12 15:48:37             0.0
# 3             1              2  2018-01-09 16:44:22             0.0
# 4             1              0  2017-08-07 16:12:43             0.0
# 5             1              2  2017-08-25 05:18:31             0.0
# 6             2              1  2018-01-01 15:23:47             0.0
# 7             0              0  2018-04-16 18:50:40             0.0
# 8             1              4  2017-04-17 15:05:04             0.0
# 9             0              7  2018-03-06 03:55:41             0.0
#
#    post_type_id  score                                               tags  \
# 0             1      0  <python><cloud><telegram><telegram-bot><server...
# 1             1     22             <python><python-3.x><pandas><indexing>
# 2             1      1                               <python><python-3.x>
# 3             1     -4                               <python><python-3.x>
# 4             1      0    <python><node.js><scikit-learn><pickle><joblib>
# 5             1      0                  <python><python-3.x><pyqt><pyqt5>
# 6             1      0                                     <python><kivy>
# 7             1      0                 <python><graphql><graphene-python>
# 8             1      0                              <python><apscheduler>
# 9             1      0                      <python-3.x><urllib><urlopen>
#
#    view_count
# 0         172
# 1       77602
# 2         223
# 3          35
# 4         342
# 5         223
# 6         467
# 7         231
# 8         715
# 9         460

# %%
def get_avg_accepted(word):#get single word avg_favor count
    avg=0
    len_avg=0
    for i in range(len(df)):
        if word in df["body"].values[i]:
            len_avg+=1
            if df["accepted_answer_id"].values[i]!=0:
                avg+=1
        else:
            continue
    if len_avg==0:
        return 0
    return(avg/len_avg)
def topic_accepted(word):
    topic_accepted=[]
    func=lambda x,y:x*y
    for i in range(len(word)):
        topic=[]
        for j in word[i]:
            topic.append(get_avg_accepted(j))
        topic_favorite_count=sum(map(func,topic,all_clean_num[i]))
        topic_accepted.append(topic_favorite_count)
    return topic_accepted
topic_accepted(word)
# Out:
# [0.4312189771383722,
#  0.4208294572880168,
#  0.4395011272610458,
#  0.4108312422074892,
#  0.4215759529555552,
#  0.41750430454943915,
#  0.446724674469918,
#  0.39139590194873564,
#  0.45021753414202903,
#  0.453116703836061,
#  0.41432999558951844,
#  0.41287959326852325,
#  0.4013722533310365,
#  0.47619613787217097,
#  0.44186230457328224,
#  0.42927455685502214,
#  0.4013572749759513,
#  0.4355052161450952,
#  0.4204492237769303,
#  0.4385180228975362,
#  0.39486129433253897,
#  0.4311682781593309,
#  0.5164974783275786,
#  0.4303351054501784,
#  0.47151837344358494,
#  0.43651384625830014,
#  0.3963878607964201,
#  0.4548245580273925,
#  0.4479686768723814,
#  0.4504190675592747]

# %%
#df[710000:len(df)].to_csv("train_data02.csv",encoding="latin1")

# %%
def get_avg(word):
    avg=0
    len_avg=0
    for i in range(len(df)):
        if word in df["body"].values[i]:
            len_avg+=1
            avg+=df["score"].values[i]
        else:
            continue
    if len_avg==0:
        return 0
    return (avg/len_avg)
#get_avg("")
def get_avg_score(word):
    all_topic_avg=[]
    func = lambda x,y:x*y
    for i in range(len(word)):
        topic_avg=[]
        for j in  word[i]:
            topic_avg.append(get_avg(j))
        topic_avg_score=sum(map(func,topic_avg,all_clean_num[i]))
        #topic_avg_score=sum(topic_avg_score)
        all_topic_avg.append(topic_avg_score)
    return all_topic_avg
get_avg_score(word)
# Out:
# [0.5739712917603261,
#  0.49829643795122086,
#  0.639391596192161,
#  0.7161467503844862,
#  0.5681514193143643,
#  0.5650345203538345,
#  0.6322532934038622,
#  0.5516516984322717,
#  0.5476261511486711,
#  0.551816878441754,
#  0.5729199209145728,
#  0.5940251981941521,
#  0.5943964049544364,
#  0.6058311270362676,
#  0.5859643431490872,
#  0.6655928542811161,
#  0.5882182052274798,
#  0.6077847373900308,
#  0.6143301981641602,
#  0.5684653494697108,
#  0.5645134480355195,
#  0.5737235043347597,
#  0.6928214257870646,
#  0.5705520991689914,
#  0.6020768038261455,
#  0.6170631868668753,
#  0.6050768769865635,
#  0.5909459959101453,
#  0.5896608670257831,
#  0.6115173458313304]
